# %% [markdown]
# # Basic regression tests

# %%
import warnings
warnings.filterwarnings('ignore')

from model_tools.regression import *
from model_tools.utils import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Single variable linear function without noise.
#
# The closed form of the function is $y=ax+b$.

# %% [markdown]
# ### Test 1 : $a=1$, $b=0$.

# %%
x = np.array(range(100))
y = np.array(range(100))
data1 = pd.DataFrame({'x':x.tolist(), 'y':y.tolist()})
data1.head()
# Out:
#    x  y
# 0  0  0
# 1  1  1
# 2  2  2
# 3  3  3
# 4  4  4

# %%
from sklearn.linear_model import LinearRegression
reg = Regressor(LinearRegression(), "lr")
data = Data(data1, ['x'], 'y', 0.2)
setting = Setting(transforming_strategy="")
p1 = CustomPipeline(reg, data, setting)
p1.get_summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       3 data = Data(data1, ['x'], 'y', 0.2)
#       4 setting = Setting(transforming_strategy="")
# ----> 5 p1 = CustomPipeline(reg, data, setting)
#       6 p1.get_summary()
#
# File ~\anaconda3\envs\datascience\lib\site-packages\model_tools\regression.py:36, in CustomPipeline.__init__(self, regressor, data, setting)
#      34 self.data = data
#      35 self.setting = setting
# ---> 36 self._fit_model()
#
# File ~\anaconda3\envs\datascience\lib\site-packages\model_tools\regression.py:108, in CustomPipeline._fit_model(self)
#     104 def _fit_model(self):
#     105     """
#     106     Fits custom model pipeline with given data and set of features.
#     107     """
# --> 108     self.model = self._modeler().fit(self.data.X_train, self.data.y_train)
#
# File ~\anaconda3\envs\datascience\lib\site-packages\sklearn\pipeline.py:402, in Pipeline.fit(self, X, y, **fit_params)
#     376 """Fit the model.
#     377
#     378 Fit all the transformers one after the other and transform the
#    (...)
#     399     Pipeline with fitted steps.
#     400 """
#     401 fit_params_steps = self._check_fit_params(**fit_params)
# --> 402 Xt = self._fit(X, y, **fit_params_steps)
#     403 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     404     if self._final_estimator != "passthrough":
#
# File ~\anaconda3\envs\datascience\lib\site-packages\sklearn\pipeline.py:360, in Pipeline._fit(self, X, y, **fit_params_steps)
#     358     cloned_transformer = clone(transformer)
#     359 # Fit or load from cache the current transformer
# --> 360 X, fitted_transformer = fit_transform_one_cached(
#     361     cloned_transformer,
#     362     X,
#     363     y,
#     364     None,
#     365     message_clsname="Pipeline",
#     366     message=self._log_message(step_idx),
#     367     **fit_params_steps[name],
#     368 )
#     369 # Replace the transformer of the step with the fitted
#     370 # transformer. This is necessary when loading the transformer
#     371 # from the cache.
#     372 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~\anaconda3\envs\datascience\lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~\anaconda3\envs\datascience\lib\site-packages\sklearn\pipeline.py:894, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     892 with _print_elapsed_time(message_clsname, message):
#     893     if hasattr(transformer, "fit_transform"):
# --> 894         res = transformer.fit_transform(X, y, **fit_params)
#     895     else:
#     896         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\envs\datascience\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\anaconda3\envs\datascience\lib\site-packages\sklearn\compose\_column_transformer.py:722, in ColumnTransformer.fit_transform(self, X, y)
#     720 # set n_features_in_ attribute
#     721 self._check_n_features(X, reset=True)
# --> 722 self._validate_transformers()
#     723 self._validate_column_callables(X)
#     724 self._validate_remainder(X)
#
# File ~\anaconda3\envs\datascience\lib\site-packages\sklearn\compose\_column_transformer.py:409, in ColumnTransformer._validate_transformers(self)
#     405     continue
#     406 if not (hasattr(t, "fit") or hasattr(t, "fit_transform")) or not hasattr(
#     407     t, "transform"
#     408 ):
# --> 409     raise TypeError(
#     410         "All estimators should implement fit and "
#     411         "transform, or can be 'drop' or 'passthrough' "
#     412         "specifiers. '%s' (type %s) doesn't." % (t, type(t))
#     413     )
#
# TypeError: All estimators should implement fit and transform, or can be 'drop' or 'passthrough' specifiers. 'None' (type <class 'NoneType'>) doesn't.

# %%
predictions = p1.get_prediction()

plt.scatter(data=data1, x='x', y='y', s=5, c='blue')
plt.scatter(x=p1.data.X_test, y=predictions, s=5, c='red')
plt.show()

# %% [markdown]
# ### Test 2: $a=1$, $b=-20.$

# %%
x = np.array(range(100))
y = np.array(range(100))-20
data2 = pd.DataFrame({'x':x.tolist(), 'y':y.tolist()})
data2.head()
# Out:
#    x   y
# 0  0 -20
# 1  1 -19
# 2  2 -18
# 3  3 -17
# 4  4 -16

# %%
reg = Regressor(LinearRegression(), "lr")
data = Data(data2, ['x'], 'y', 0.2)
setting = Setting()
p2 = CustomPipeline(reg, data, setting)
p2.get_summary()
# Out:
# Model training score: 0.9969192434895061
# Model prediction score: 0.9952739182758421
# Model RMSE: 2.0315680417968554
# Model MAE: 1.5402763879231298

# %%
predictions = test2.get_fitted_model().predict(data2)

plt.scatter(data=data2, x='x', y='y', s=5, c='blue')
plt.scatter(x=data2['x'], y=predictions, s=5, c='red')
plt.show()

# %% [markdown]
# ## Single variable linear function with noise.
#
# The closed form of the function is $y=ax+b$.

# %% [markdown]
# ### Test 3: $a=1$, $b=0$.

# %%
x = np.array(range(100))
y = np.array(range(100))+np.random.randn(100)
data3 = pd.DataFrame({'x':x.tolist(), 'y':y.tolist()})
data3.head()
# Out:
#    x         y
# 0  0  0.364961
# 1  1  1.649208
# 2  2  1.164871
# 3  3  1.183729
# 4  4  4.473847

# %%
test3 = Tester(LinearRegression(), data=data3, features=['x'], target='y')
test3.get_summary()
# Out:
# Model training score: 0.9986743232496358
# Model prediction score: 0.999116168650745
# Model RMSE: 0.9332173095450746

# %%
predictions = test3.get_fitted_model().predict(data3)

plt.scatter(data=data3, x='x', y='y', s=5, c='blue')
plt.scatter(x=data3['x'], y=predictions, s=5, c='red')
plt.show()

# %% [markdown]
# ### Test 4: $a=1$, $b=-20$.

# %%
x = np.array(range(100))
y = np.array(range(100))-20 + 3*np.random.randn(100)
data4 = pd.DataFrame({'x':x.tolist(), 'y':y.tolist()})
data4.head()
# Out:
#    x          y
# 0  0 -22.499584
# 1  1 -16.982812
# 2  2 -15.604621
# 3  3 -15.422562
# 4  4 -16.362680

# %%
test4 = Tester(LinearRegression(), data=data4, features=['x'], target='y')
test4.get_summary()
# Out:
# Model training score: 0.9887764204231265
# Model prediction score: 0.9887995537157273
# Model RMSE: 3.3762943809576127

# %%
predictions = test4.get_fitted_model().predict(data4)

plt.scatter(data=data4, x='x', y='y', s=5, c='blue')
plt.scatter(x=data4['x'], y=predictions, s=5, c='red')
plt.show()
